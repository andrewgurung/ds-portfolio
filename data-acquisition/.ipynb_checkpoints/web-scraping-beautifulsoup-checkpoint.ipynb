# %% [markdown]
# # Web Scraping with BeautifulSoup
#
# Web scraping is a technique to extract data from multiple web pages. [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/) is a Python library designed for quick turnaround projects like screen-scraping.
#
# ## What are we scraping?
# Virginia Dangerous Dog Registry is a **public**, searchable online database of dogs declared dangerous by local courts. It also serves as the mechanism by which local animal control officers must report dangerous dogs to the Virginia Department of Agriculture and Consumer Services.
#
# Source: https://dd.va-vdacs.com/
#
# ## Table of Contents:
# 1. [Import dependencies](#Install-and-Import-dependencies)
# 2. [Make a POST request](#Make-a-POST-request)
# 3. [Extracting Content from HTML](#Extracting-Content-from-HTML)
# 4. [Writing to a CSV](#Writing-to-a-CSV)

# %% [markdown]
# ## Install and import dependencies
#
# Install these two packages using the pip installer.
#
# ```console
# $ pip install requests
# $ pip install beautifulsoup4
# ```
#
# Import Dependencies
# 1. Restful Call: *requests*
# 2. BeautifulSoup: *BeautifulSoup*
# 3. Regular Expressions: *re*

# %%
# import dependencies
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## Make a POST request
# Make a POST request with post data to get the search result

# %%
# compose the post data that returns the entire search result
postData = {'SYSJURISNO': 0,
            'DD_TAG_NO': '', 
            'NAME': '', 
            'HOME_ADDRESS': '',
            'HOME_ZIP': ''}

# make a POST request
r = requests.post('https://dd.va-vdacs.com/Public/PublicSearch', data=postData)

# %% [markdown]
# Inspecting the Response

# %%
# inspecting status code
print(r.status_code)
# Out:
# 200

# %%
# inspecting the response
print(r.text)
# Out:
#     <p class="text-center" style="font-weight: bold;">Search results ( 548 dogs )</p>
#     <table class="table table-condensed table-hover">
#         <tr style="font-size: .95em;">
#             <th>Locality</th>
#             <th>Dog Name</th>
#             <th>Dangerous Dog Tag #</th>
#             <th>Address</th>
#             <th>City</th>
#             <th>Zip</th>
#             <th class="text-center">Details</th>
#         </tr>
#             <tr>
#                 <td>Accomack County</td>
#                 <td>Bentley</td>
#                 <td>0156</td>
#                 <td>22094 Sawyer Dr
#                 <td>Greenbush
#                 <td>23357
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1432" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Jaxson Luis Alvarez</td>
#                 <td>1538</td>
#                 <td>580 Radford Lane #207
#                 <td>Charlottesville
#                 <td>22903
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1638" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Kujo</td>
#                 <td>2052</td>
#                 <td>1398 Lonesome Mountain Hollow
#                 <td>Charlottesville
#                 <td>22903
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1279" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Blockhead</td>
#                 <td>1657</td>
#                 <td>8095 Langhorn Road
#                 <td>Scottsville
#                 <td>24590
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/918" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Max</td>
#                 <td>2057</td>
#                 <td>3558 Layton Drive
#                 <td>Charlottesville
#                 <td>22903
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/427" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Chipper</td>
#                 <td>2501</td>
#                 <td>2420 Kimbrough Cir
#                 <td>Charlottesville
#                 <td>22901
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1657" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Albemarle County</td>
#                 <td>Kingston</td>
#                 <td>2055</td>
#                 <td>1878 Secretarys Drive
#                 <td>Scottsville
#                 <td>24590
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1313" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>
style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Chesterfield County</td>
#                 <td>Bash</td>
#                 <td>2927</td>
#                 <td>3501 Oregon Oak Dr.
#                 <td>N. Chesterfield
#                 <td>23234
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1540" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Macho</td>
#                 <td>1340</td>
#                 <td>5355 Taney Ave. #202
#                 <td>Alexandria
#                 <td>22304
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/958" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Henry</td>
#                 <td>1337</td>
#                 <td>305 Duke Street
#                 <td>Alexandria
#                 <td>22314
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/835" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Ava</td>
#                 <td>2891</td>
#                 <td>2705 Mosby St
#                 <td>Alexandria
#                 <td>22305
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1374" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Sender</td>
#                 <td>2893</td>
#                 <td>808 Junior St
#                 <td>Alexandria
#                 <td>22301
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1570" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Tipper</td>
#                 <td>133</td>
#                 <td>3502 16th Steet South
#                 <td>Arlington
#                 <td>22204
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1024" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Budreaux</td>
#                 <td>2895</td>
#                 <td>17 E Del Ray Ave
#                 <td>Alexandria
#                 <td>22301
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1569" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Otto</td>
#                 <td>2897</td>
#                 <td>203 Wolfe St
#                 <td>Alexandria
#                 <td>22314
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1692" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Alexandria</td>
#                 <td>Mr. Peabody</td>
#                 <td>1339</td>
#                 <td>1210 Powhatan Street
#                 <td>Alexandria
#                 <td>22314
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/818" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Buena Vista</td>
#                 <td>Lilly</td>
#                 <td>018</td>
#                 <td>144 E 9th St
#                 <td>Buena Vista
#                 <td>24416
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1508" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Charlottesville</td>
#                 <td>Stryker</td>
#                 <td>106</td>
#                 <td>No fixed address
#                 <td>Charlottesville
#                 <td>22902
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1664" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Chesapeake</td>
#                 <td>Cocoa</td>
#                 <td>2084</td>
#                 <td>2808 Point Harbor Ct
#                 <td>Chesapeake
#                 <td>23321
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1239" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Chesapeake</td>
#                 <td>Sable</td>
#                 <td>2083</td>
#                 <td>2808 Point Harbor Ct
#                 <td>Chesapeake
#                 <td>23321
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1240" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Chesapeake</td>
#                 <td>Jameson</td>
#                 <td>1887</td>
#                 <td>3133 Dunworken Dr
#                 <td>Chesapeake
#                 <td>23321
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1172" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Chesapeake</td>
#                 <td>Dulce</td>
#                 <td>1404</td>
#                 <td>1601 Muscovy Ct
#                 <td>Chesapeake
#                 <td>23320
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1099" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>City of Chesapeake</td>
#                 <td>Ollie</td>
#                 <td>600014</td>
#                 <td>1120 Willow Avenue
#                 <td>Chesapeake
#                 <td>23325
#                 </td>
#                 <td class="text-center">
# ...
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1005" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Stafford County</td>
#                 <td>BLITZ</td>
#                 <td>0528</td>
#                 <td>1129 ATLANTIC DRIVE
#                 <td>STAFFORD
#                 <td>22554
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/898" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Stafford County</td>
#                 <td>Casey</td>
#                 <td>0540</td>
#                 <td>227 Rock Raymond Dr
#                 <td>Stafford
#                 <td>22554
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1188" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Stafford County</td>
#                 <td>Nicki</td>
#                 <td>0537</td>
#                 <td>18 Willow Branch Dr
#                 <td>Fredericksburg
#                 <td>22405
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1059" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1668" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Warren County</td>
#                 <td>BO</td>
#                 <td>2663</td>
#                 <td>615 New Avenue
#                 <td>Front Royal
#                 <td>22630
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1669" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Westmoreland County</td>
#                 <td>Tyson</td>
#                 <td>003</td>
#                 <td>68 Tiana Way, P.O. Box 165
#                 <td>Mt. Holly
#                 <td>22524
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/1451" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Wise County</td>
#                 <td>Brutus</td>
#                 <td>0560</td>
#                 <td>217 Shawnee Ave West
#                 <td>Big Stone Gap
#                 <td>24219
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/89" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>Wise County</td>
#                 <td>Josie Bell Wright</td>
#                 <td>0565</td>
#                 <td>209 Azalea Drive
#                 <td>Wise
#                 <td>24293
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/919" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#             <tr>
#                 <td>York County</td>
#                 <td>Riley</td>
#                 <td>0151</td>
#                 <td>315 Waller Mill Rd
#                 <td>Williamsburg
#                 <td>23185
#                 </td>
#                 <td class="text-center">
#                     <a data-ajax="true" data-ajax-mode="replace" data-ajax-success="ShowDetails" data-ajax-update="#dvDetails" href="/Public/Details/986" style="text-decoration:none;padding-left:15px;padding-right:15px;">Details</a>
#                 </td>
#             </tr>
#
#     </table>
#
# <div id="dvDetails" tabindex="-1" style="margin-top: 10px">
#     <!-- Placeholder for Details  -->
# </div>
#
#
#
#
# <script type="text/javascript">
#
#     function ShowDetails() {
#         document.getElementById("dvDetails").focus();
#     }
#
# </script>

# %% [markdown]
# ## Extracting Content from HTML
# Note: The search results return 548 dogs with an additional header row.

# %%
# Parse HTML DOM structure
soup = BeautifulSoup(r.text, "html.parser")

# entire search result
table = soup.table

# list of rows
rows = table.findAll('tr')
len(rows)
# Out:
# 549

# %%
# list of dogs without the details column
dogs = [
    ['Locality', 'Dog Name', 'Dangerous Dog Tag #', 'Address', 'City', 'Zip']
]

# remove header row
rows = rows[1:]

# extract dog information from result
for row in rows:
    tds = row.findAll('td')
    dog = []
    for td in tds[:6]:
      dog.append(td.text.strip())
    dogs.append(dog)
    
dogs[:5]
# Out:
# [['Locality', 'Dog Name', 'Dangerous Dog Tag #', 'Address', 'City', 'Zip'],
#  ['Albemarle County',
#   'Jaxson Luis Alvarez',
#   '1538',
#   '580 Radford Lane #207\r\n                Charlottesville\r\n                22903\r\n                \n\nDetails',
#   'Charlottesville\r\n                22903\r\n                \n\nDetails',
#   '22903'],
#  ['Albemarle County',
#   'Kujo',
#   '2052',
#   '1398 Lonesome Mountain Hollow\r\n                Charlottesville\r\n                22903\r\n                \n\nDetails',
#   'Charlottesville\r\n                22903\r\n                \n\nDetails',
#   '22903'],
#  ['Albemarle County',
#   'Blockhead',
#   '1657',
#   '8095 Langhorn Road\r\n                Scottsville\r\n                24590\r\n                \n\nDetails',
#   'Scottsville\r\n                24590\r\n                \n\nDetails',
#   '24590'],
#  ['Albemarle County',
#   'Max',
#   '2057',
#   '3558 Layton Drive\r\n                Charlottesville\r\n                22903\r\n                \n\nDetails',
#   'Charlottesville\r\n                22903\r\n                \n\nDetails',
#   '22903']]

# %%
To be continued:
    - Address is a nested <td> element
    - Remove details column

# %% [markdown]
# ## Writing to a CSV
